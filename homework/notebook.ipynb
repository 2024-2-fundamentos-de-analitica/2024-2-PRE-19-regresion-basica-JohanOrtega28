# %%
import pandas as pd

dataset = pd.read_csv("../files/input/auto_mpg.csv")
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %%
#
# Tamaño del dataset
#
dataset.shape
# Out:
# (398, 8)

# %%
#
# Búsqueda de valores nulos
#
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
#
# Se eliminan los registros nulos
#
dataset = dataset.dropna()
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
#
# Columna Origin
# Nota:  1) USA
#        2) Europe
#        3) Japan
dataset.Origin.value_counts()
# Out:
# Origin
# 1    245
# 3     79
# 2     68
# Name: count, dtype: int64

# %%
#
# Convierte la columna a categorias
# Nota. Realmente no se debería hacer asi para aplicaciones
# en productivo
#
dataset["Origin"] = dataset["Origin"].map(
    {1: "USA", 2: "Europe", 3: "Japan"},
)

# %%
#
# Genera variables dummy para indicar la procedencia
#
dataset = pd.get_dummies(dataset, columns=["Origin"], prefix="", prefix_sep="")
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Europe  Japan   USA
# 0          70   False  False  True
# 1          70   False  False  True
# 2          70   False  False  True
# 3          70   False  False  True
# 4          70   False  False  True

# %%
#
# Note que aca no se usa train_test_split
#
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
#
# Las millas por galon (MPG) son función de las demas variables.
#
import seaborn as sns

sns.pairplot(
    train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       1 #
#       2 # Las millas por galon (MPG) son función de las demas variables.
#       3 #
#       4 import seaborn as sns
#       6 sns.pairplot(
# ----> 7     train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde"
#       8 )
#
# NameError: name 'train_dataset' is not defined

# %%
#
# Cálculo de algunas estadísticas generales
#
train_dataset.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# MPG           314.0    23.310510    7.728652    10.0    17.00    22.0
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
#
#                   75%     max
# MPG             28.95    46.6
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0

# %%
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_labels = train_features.pop("MPG")
test_labels = test_features.pop("MPG")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 train_features = train_dataset.copy()
#       2 test_features = test_dataset.copy()
#       4 train_labels = train_features.pop("MPG")
#
# NameError: name 'train_dataset' is not defined

# %%
train_dataset.describe().transpose()[["mean", "std"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_dataset.describe().transpose()[["mean", "std"]]
#
# NameError: name 'train_dataset' is not defined

# %%
#
# Efecto del StandardScaler
#
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

pd.DataFrame(
    data=scaler.fit_transform(train_dataset),
    columns=train_dataset.columns,
).describe().transpose()[["mean", "std"]]
# Out:
#                       mean       std
# MPG          -2.206303e-16  1.001596
# Cylinders     2.022444e-16  1.001596
# Displacement  7.990777e-17  1.001596
# Horsepower   -1.980016e-17  1.001596
# Weight       -9.051500e-17  1.001596
# Acceleration -5.275327e-16  1.001596
# Model Year    9.419217e-16  1.001596
# Europe        3.394312e-17  1.001596
# Japan         2.828594e-18  1.001596
# USA           1.697156e-17  1.001596

# %%
#
# REGRESION LINEAL CON UN VARIABLE
# ------------------------------------------------------
#
# Preparación de la data
#
horsepower_scaler = StandardScaler()

train_horsepower = train_features[["Horsepower"]]
test_horsepower = test_features[["Horsepower"]]

horsepower_scaler.fit(train_horsepower)

standarized_train_horsepower = horsepower_scaler.transform(train_horsepower)
standarized_test_horsepower = horsepower_scaler.transform(test_horsepower)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       1 #
#       2 # REGRESION LINEAL CON UN VARIABLE
#       3 # ------------------------------------------------------
#       4 #
#       5 # Preparación de la data
#       6 #
# ----> 7 horsepower_scaler = StandardScaler()
#       9 train_horsepower = train_features[["Horsepower"]]
#      10 test_horsepower = test_features[["Horsepower"]]
#
# NameError: name 'StandardScaler' is not defined

# %%
#
# Modelo de regresión lineal
#
from sklearn.linear_model import LinearRegression

horsepower_model = LinearRegression()
horsepower_model.fit(standarized_train_horsepower, train_labels)
# Out:
# LinearRegression()

# %%
#
# Intercepto
#
horsepower_model.intercept_
# Out:
# np.float64(23.31050955414013)

# %%
#
# Coeficientes
#
horsepower_model.coef_
# Out:
# array([-5.89948889])

# %%
#
# Predicción. Preparación de las variables independientes
#
import numpy as np

x = pd.DataFrame({"Horsepower": np.linspace(0, 250, 251)})
x.head()
# Out:
#    Horsepower
# 0         0.0
# 1         1.0
# 2         2.0
# 3         3.0
# 4         4.0

# %%
#
# Predicción
#
scaled_x = horsepower_scaler.transform(x)
y = horsepower_model.predict(scaled_x)
y[:5]
# Out:
# array([39.57626034, 39.42115555, 39.26605075, 39.11094596, 38.95584117])

# %%
import matplotlib.pyplot as plt


def plot_horsepower(x, y):
    plt.scatter(train_features["Horsepower"], train_labels, label="Data")
    plt.plot(x, y, color="k", label="Predictions")
    plt.xlabel("Horsepower")
    plt.ylabel("MPG")
    plt.legend()

# %%
plot_horsepower(x, y)

# %%
#
# Evaluación
#
from sklearn.metrics import mean_squared_error

test_results = {}

y_pred = horsepower_model.predict(standarized_test_horsepower)

test_results["horsepower_model"] = mean_squared_error(
    y_true=test_labels,
    y_pred=y_pred,
)

test_results
# Out:
# {'horsepower_model': 20.829300555790315}

# %%
#
# Preparación de la data
#
features_scaler = StandardScaler()

features_scaler.fit(train_features)

standarized_train_features = features_scaler.transform(train_features)
standarized_test_features = features_scaler.transform(test_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 #
#       2 # Preparación de la data
#       3 #
# ----> 4 features_scaler = StandardScaler()
#       6 features_scaler.fit(train_features)
#       8 standarized_train_features = features_scaler.transform(train_features)
#
# NameError: name 'StandardScaler' is not defined

# %%
linear_model = LinearRegression()
linear_model.fit(standarized_train_features, train_labels)
# Out:
# LinearRegression()

# %%
#
# Intercepto
#
linear_model.intercept_
# Out:
# np.float64(23.310509554140125)

# %%
#
# Coeficientes
#
linear_model.coef_
# Out:
# array([-0.78715361,  2.40329414, -1.35280162, -5.10984346, -0.26461302,
#         2.92072687,  0.42671757,  0.57369578, -0.80879752])

# %%
def plot_predictions(y_true, y_pred):

    ax = plt.axes(aspect="equal")
    plt.scatter(y_true, y_pred)
    plt.xlabel("True Values [MPG]")
    plt.ylabel("Predictions [MPG]")
    lims = [0, 50]
    plt.xlim(lims)
    plt.ylim(lims)
    _ = plt.plot(lims, lims)

# %%
    
test_predictions = linear_model.predict(standarized_test_features)

plot_predictions(
    y_true=test_labels,
    y_pred=test_predictions,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 test_predictions = linear_model.predict(standarized_test_features)
#       3 plot_predictions(
#       4     y_true=test_labels,
#       5     y_pred=test_predictions,
#       6 )
#
# NameError: name 'linear_model' is not defined

# %%
#
# RED NEURONAL CON UNA SOLA ENTRADA
# ------------------------------------------------------
#
from sklearn.neural_network import MLPRegressor

mlp_horsepower = MLPRegressor(
    max_iter=10000,
    hidden_layer_sizes=(64, 64),
    activation="relu",
    solver="adam",
    learning_rate_init=0.001,
    validation_fraction=0.2,
    early_stopping=True,
    random_state=0,
)
mlp_horsepower.fit(standarized_train_horsepower, train_labels)

y = mlp_horsepower.predict(scaled_x)
plot_horsepower(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 17
#       5 from sklearn.neural_network import MLPRegressor
#       7 mlp_horsepower = MLPRegressor(
#       8     max_iter=10000,
#       9     hidden_layer_sizes=(64, 64),
#    (...)
#      15     random_state=0,
#      16 )
# ---> 17 mlp_horsepower.fit(standarized_train_horsepower, train_labels)
#      19 y = mlp_horsepower.predict(scaled_x)
#      20 plot_horsepower(x, y)
#
# NameError: name 'standarized_train_horsepower' is not defined

# %%
y_pred = mlp_horsepower.predict(standarized_test_horsepower)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 y_pred = mlp_horsepower.predict(standarized_test_horsepower)
#
# NameError: name 'standarized_test_horsepower' is not defined

# %%
test_results["mlp_horsepower"] = mean_squared_error(
    y_true=test_labels,
    y_pred=y_pred,
)

test_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 test_results["mlp_horsepower"] = mean_squared_error(
#       2     y_true=test_labels,
#       3     y_pred=y_pred,
#       4 )
#       6 test_results
#
# NameError: name 'mean_squared_error' is not defined

# %%
#
# RED NEURONAL CON TODAS LAS VARIABLES
# ------------------------------------------------------
#
mlp = MLPRegressor(
    max_iter=10000,
    hidden_layer_sizes=(64, 64),
    activation="relu",
    solver="adam",
    learning_rate_init=0.001,
    validation_fraction=0.2,
    early_stopping=True,
    random_state=0,
)
mlp.fit(standarized_train_features, train_labels)

# %%
test_predictions = mlp.predict(standarized_test_features)

plot_predictions(
      y_true=test_labels,
      y_pred=test_predictions,
  )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 test_predictions = mlp.predict(standarized_test_features)
#       3 plot_predictions(
#       4       y_true=test_labels,
#       5       y_pred=test_predictions,
#       6   )
#
# NameError: name 'mlp' is not defined

# %%
test_results["mlp"] = mean_squared_error(
    y_true=test_labels,
    y_pred=test_predictions,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test_results["mlp"] = mean_squared_error(
#       2     y_true=test_labels,
#       3     y_pred=test_predictions,
#       4 )
#
# NameError: name 'mean_squared_error' is not defined

# %%
pd.DataFrame(test_results, index=["Mean squared error [MPG]"]).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.DataFrame(test_results, index=["Mean squared error [MPG]"]).T
#
# NameError: name 'pd' is not defined

# %%
#
# ALMACENAMIENTO DEL MODELO
#
import pickle

with open("mlp.pickle", "wb") as file:
    pickle.dump(mlp, file)

with open("features_scaler.pickle", "wb") as file:
    pickle.dump(features_scaler, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 import pickle
#       6 with open("mlp.pickle", "wb") as file:
# ----> 7     pickle.dump(mlp, file)
#       9 with open("features_scaler.pickle", "wb") as file:
#      10     pickle.dump(features_scaler, file)
#
# NameError: name 'mlp' is not defined

# %%
#
# USO DEL MODELO
#
import pandas as pd

dataset = pd.read_csv("../files/input/auto_mpg.csv")
dataset = dataset.dropna()
dataset["Origin"] = dataset["Origin"].map(
    {1: "USA", 2: "Europe", 3: "Japan"},
)
dataset = pd.get_dummies(dataset, columns=["Origin"], prefix="", prefix_sep="")
y_true = dataset.pop("MPG")


with open("mlp.pickle", "rb") as file:
    new_mlp = pickle.load(file)

with open("features_scaler.pickle", "rb") as file:
    new_features_scaler = pickle.load(file)

standarized_dataset = new_features_scaler.transform(dataset)
y_pred = mlp.predict(standarized_dataset)

mean_squared_error(
    y_true=y_true,
    y_pred=y_pred,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 16
#      12 y_true = dataset.pop("MPG")
#      15 with open("mlp.pickle", "rb") as file:
# ---> 16     new_mlp = pickle.load(file)
#      18 with open("features_scaler.pickle", "rb") as file:
#      19     new_features_scaler = pickle.load(file)
#
# NameError: name 'pickle' is not defined
